# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: chembl_webresource_client in /home/bruno/.local/lib/python3.10/site-packages (0.10.9)
# Requirement already satisfied: easydict in /home/bruno/.local/lib/python3.10/site-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: requests>=2.18.4 in /home/bruno/.local/lib/python3.10/site-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: urllib3 in /usr/lib/python3/dist-packages (from chembl_webresource_client) (1.26.5)
# Requirement already satisfied: requests-cache~=1.2 in /home/bruno/.local/lib/python3.10/site-packages (from chembl_webresource_client) (1.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/bruno/.local/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2020.6.20)
# Requirement already satisfied: url-normalize>=1.4 in /home/bruno/.local/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: cattrs>=22.2 in /home/bruno/.local/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/bruno/.local/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (4.2.2)
# Requirement already satisfied: attrs>=21.2 in /home/bruno/.local/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /home/bruno/.local/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.1)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /home/bruno/.local/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0   [{'xref_id': 'P22303', 'xref_name': None, 'xre...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [{'xref_id': 'P04058', 'xref_name': None, 'xre...
# 6   [{'xref_id': 'P21836', 'xref_name': None, 'xre...
# 7   [{'xref_id': 'P37136', 'xref_name': None, 'xre...
# 8   [{'xref_id': 'O42275', 'xref_name': None, 'xre...
# 9   [{'xref_id': 'P23795', 'xref_name': None, 'xre...
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15  [{'xref_id': 'Q95P20', 'xref_name': None, 'xre...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
#
#                      organism  \
# 0                Homo sapiens
# 1                Homo sapiens
# 2     Drosophila melanogaster
# 3              Bemisia tabaci
# 4   Leptinotarsa decemlineata
# 5         Torpedo californica
# 6                Mus musculus
# 7           Rattus norvegicus
# 8    Electrophorus electricus
# 9                  Bos taurus
# 10          Anopheles gambiae
# 11     Nephotettix cincticeps
# 12              Gallus gallus
# 13                Danio rerio
# 14              Aedes aegypti
# 15            Musca domestica
# 16          Rattus norvegicus
# 17        Plutella xylostella
# 18            Musca domestica
# 19  Pediculus humanus capitis
# 20          Spodoptera litura
# 21      Laodelphax striatella
# 22        Schizaphis graminum
# 23     Caenorhabditis elegans
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   28.0
# 1                        Cholinesterases; ACHE & BCHE   28.0
# 2                                Acetylcholinesterase   18.0
# 3                                               AChE2   16.0
# 4                                Acetylcholinesterase   16.0
# 5                                Acetylcholinesterase   15.0
# 6                                Acetylcholinesterase   15.0
# 7                                Acetylcholinesterase   15.0
# 8                                Acetylcholinesterase   15.0
# 9                                Acetylcholinesterase   15.0
# 10                               Acetylcholinesterase   15.0
# 11               Ace-orthologous acetylcholinesterase   15.0
# 12                               Acetylcholinesterase   15.0
# 13                               Acetylcholinesterase   15.0
# 14                               Acetylcholinesterase   15.0
# 15                               Acetylcholinesterase   14.0
# 16  Acetylcholinesterase and butyrylcholinesterase...   14.0
# 17                               Acetylcholinesterase   14.0
# 18                               Acetylcholinesterase   14.0
# 19                               Acetylcholinesterase   14.0
# 20                               Acetylcholinesterase   14.0
# 21                               Acetylcholinesterase   14.0
# 22                               Acetylcholinesterase   14.0
# 23                             Acetylcholinesterase 1   14.0
#
#     species_group_flag target_chembl_id  \
# 0                False        CHEMBL220
# 1                False    CHEMBL2095233
# 2                False    CHEMBL2242744
# 3                False    CHEMBL2366409
# 4                False    CHEMBL2366490
# 5                False       CHEMBL4780
# 6                False       CHEMBL3198
# 7                False       CHEMBL3199
# 8                False       CHEMBL4078
# 9                False       CHEMBL4768
# 10               False    CHEMBL2046266
# 11               False    CHEMBL2366514
# 12               False    CHEMBL3227914
# 13               False    CHEMBL3308995
# 14               False    CHEMBL4295607
# 15               False       CHEMBL5752
# 16               False    CHEMBL2111475
# 17               False    CHEMBL2242729
# 18               False    CHEMBL2242743
# 19               False    CHEMBL2362988
# 20               False    CHEMBL2366422
# 21               False    CHEMBL2366446
# 22               False    CHEMBL2366511
# 23               False    CHEMBL3341583
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 2   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
# 17  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 23  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     9606
# 1     9606
# 2     7227
# 3     7038
# 4     7539
# 5     7787
# 6    10090
# 7    10116
# 8     8005
# 9     9913
# 10    7165
# 11   94400
# 12    9031
# 13    7955
# 14    7159
# 15    7370
# 16   10116
# 17   51655
# 18    7370
# 19  121226
# 20   69820
# 21  195883
# 22   13262
# 23    6239

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL220'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9086  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9087                                               None             None
# 9088                                               None             None
# 9089                                               None             None
# 9090  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 0           33969                  []    CHEMBL643384
# 1           37563                  []    CHEMBL643384
# 2           37565                  []    CHEMBL643384
# 3           38902                  []    CHEMBL643384
# 4           41170                  []    CHEMBL643384
# ...           ...                 ...             ...
# 9086     25111481                  []   CHEMBL5265203
# 9087     25402914                  []   CHEMBL5303778
# 9088     25402962                  []   CHEMBL5303826
# 9089     25403899                  []   CHEMBL5303876
# 9090     25406273                  []   CHEMBL5304986
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against acetylcholine...          B
# 1     Inhibitory concentration against acetylcholine...          B
# 2     Inhibitory concentration against acetylcholine...          B
# 3     Inhibitory concentration against acetylcholine...          B
# 4     Inhibitory concentration against acetylcholine...          B
# ...                                                 ...        ...
# 9086                Inhibition of AChE (unknown origin)          B
# 9087                              Cross screening panel          B
# 9088                              Cross screening panel          B
# 9089                              Cross screening panel          B
# 9090               Safety47 Scan (DiscoverX - Eurofins)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 9086                    None                   None  BAO_0000190  ...
# 9087                    None                   None  BAO_0000190  ...
# 9088                    None                   None  BAO_0000190  ...
# 9089                    None                   None  BAO_0000190  ...
# 9090                    None                   None  BAO_0000190  ...
#
#      target_organism      target_pref_name target_tax_id text_value  toid  \
# 0       Homo sapiens  Acetylcholinesterase          9606       None  None
# 1       Homo sapiens  Acetylcholinesterase          9606       None  None
# 2       Homo sapiens  Acetylcholinesterase          9606       None  None
# 3       Homo sapiens  Acetylcholinesterase          9606       None  None
# 4       Homo sapiens  Acetylcholinesterase          9606       None  None
# ...              ...                   ...           ...        ...   ...
# 9086    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9087    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9088    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9089    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9090    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#        type units    uo_units upper_value value
# 0      IC50    uM  UO_0000065        None  0.75
# 1      IC50    uM  UO_0000065        None   0.1
# 2      IC50    uM  UO_0000065        None  50.0
# 3      IC50    uM  UO_0000065        None   0.3
# 4      IC50    uM  UO_0000065        None   0.8
# ...     ...   ...         ...         ...   ...
# 9086   IC50    uM  UO_0000065        None  0.16
# 9087  pIC50  None  UO_0000065        None   5.1
# 9088  pIC50  None  UO_0000065        None   4.0
# 9089  pIC50  None  UO_0000065        None   4.2
# 9090   IC50    uM  UO_0000065        None  10.0
#
# [9091 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df3 = df2[df2.canonical_smiles.notna()]

df3
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9086  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9087                                               None             None
# 9088                                               None             None
# 9089                                               None             None
# 9090  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 0           33969                  []    CHEMBL643384
# 1           37563                  []    CHEMBL643384
# 2           37565                  []    CHEMBL643384
# 3           38902                  []    CHEMBL643384
# 4           41170                  []    CHEMBL643384
# ...           ...                 ...             ...
# 9086     25111481                  []   CHEMBL5265203
# 9087     25402914                  []   CHEMBL5303778
# 9088     25402962                  []   CHEMBL5303826
# 9089     25403899                  []   CHEMBL5303876
# 9090     25406273                  []   CHEMBL5304986
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against acetylcholine...          B
# 1     Inhibitory concentration against acetylcholine...          B
# 2     Inhibitory concentration against acetylcholine...          B
# 3     Inhibitory concentration against acetylcholine...          B
# 4     Inhibitory concentration against acetylcholine...          B
# ...                                                 ...        ...
# 9086                Inhibition of AChE (unknown origin)          B
# 9087                              Cross screening panel          B
# 9088                              Cross screening panel          B
# 9089                              Cross screening panel          B
# 9090               Safety47 Scan (DiscoverX - Eurofins)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 9086                    None                   None  BAO_0000190  ...
# 9087                    None                   None  BAO_0000190  ...
# 9088                    None                   None  BAO_0000190  ...
# 9089                    None                   None  BAO_0000190  ...
# 9090                    None                   None  BAO_0000190  ...
#
#      target_organism      target_pref_name target_tax_id text_value  toid  \
# 0       Homo sapiens  Acetylcholinesterase          9606       None  None
# 1       Homo sapiens  Acetylcholinesterase          9606       None  None
# 2       Homo sapiens  Acetylcholinesterase          9606       None  None
# 3       Homo sapiens  Acetylcholinesterase          9606       None  None
# 4       Homo sapiens  Acetylcholinesterase          9606       None  None
# ...              ...                   ...           ...        ...   ...
# 9086    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9087    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9088    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9089    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9090    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#        type units    uo_units upper_value value
# 0      IC50    uM  UO_0000065        None  0.75
# 1      IC50    uM  UO_0000065        None   0.1
# 2      IC50    uM  UO_0000065        None  50.0
# 3      IC50    uM  UO_0000065        None   0.3
# 4      IC50    uM  UO_0000065        None   0.8
# ...     ...   ...         ...         ...   ...
# 9086   IC50    uM  UO_0000065        None  0.16
# 9087  pIC50  None  UO_0000065        None   5.1
# 9088  pIC50  None  UO_0000065        None   4.0
# 9089  pIC50  None  UO_0000065        None   4.2
# 9090   IC50    uM  UO_0000065        None  10.0
#
# [7806 rows x 46 columns]

# %%
len(df3.canonical_smiles.unique())
# Out:
# 6369

# %%
df2_nr = df3.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9086  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9087                                               None             None
# 9088                                               None             None
# 9089                                               None             None
# 9090  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 0           33969                  []    CHEMBL643384
# 1           37563                  []    CHEMBL643384
# 2           37565                  []    CHEMBL643384
# 3           38902                  []    CHEMBL643384
# 4           41170                  []    CHEMBL643384
# ...           ...                 ...             ...
# 9086     25111481                  []   CHEMBL5265203
# 9087     25402914                  []   CHEMBL5303778
# 9088     25402962                  []   CHEMBL5303826
# 9089     25403899                  []   CHEMBL5303876
# 9090     25406273                  []   CHEMBL5304986
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against acetylcholine...          B
# 1     Inhibitory concentration against acetylcholine...          B
# 2     Inhibitory concentration against acetylcholine...          B
# 3     Inhibitory concentration against acetylcholine...          B
# 4     Inhibitory concentration against acetylcholine...          B
# ...                                                 ...        ...
# 9086                Inhibition of AChE (unknown origin)          B
# 9087                              Cross screening panel          B
# 9088                              Cross screening panel          B
# 9089                              Cross screening panel          B
# 9090               Safety47 Scan (DiscoverX - Eurofins)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 9086                    None                   None  BAO_0000190  ...
# 9087                    None                   None  BAO_0000190  ...
# 9088                    None                   None  BAO_0000190  ...
# 9089                    None                   None  BAO_0000190  ...
# 9090                    None                   None  BAO_0000190  ...
#
#      target_organism      target_pref_name target_tax_id text_value  toid  \
# 0       Homo sapiens  Acetylcholinesterase          9606       None  None
# 1       Homo sapiens  Acetylcholinesterase          9606       None  None
# 2       Homo sapiens  Acetylcholinesterase          9606       None  None
# 3       Homo sapiens  Acetylcholinesterase          9606       None  None
# 4       Homo sapiens  Acetylcholinesterase          9606       None  None
# ...              ...                   ...           ...        ...   ...
# 9086    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9087    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9088    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9089    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9090    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#        type units    uo_units upper_value value
# 0      IC50    uM  UO_0000065        None  0.75
# 1      IC50    uM  UO_0000065        None   0.1
# 2      IC50    uM  UO_0000065        None  50.0
# 3      IC50    uM  UO_0000065        None   0.3
# 4      IC50    uM  UO_0000065        None   0.8
# ...     ...   ...         ...         ...   ...
# 9086   IC50    uM  UO_0000065        None  0.16
# 9087  pIC50  None  UO_0000065        None   5.1
# 9088  pIC50  None  UO_0000065        None   4.0
# 9089  pIC50  None  UO_0000065        None   4.2
# 9090   IC50    uM  UO_0000065        None  10.0
#
# [6369 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 9086      CHEMBL2238282              O=C(/C=C/c1ccc(N2CCCCC2)cc1)c1sccc1Cl
# 9087      CHEMBL4636881  CC(=O)Nc1c(F)cc(C(=O)N[C@H]2CC[C@H](O)CC2)cc1O...
# 9088      CHEMBL4635134          CNC(=O)c1cc(C(=O)NC2CC2)cn(Cc2ccccc2)c1=O
# 9089      CHEMBL4639128  COCc1nc2cnc3cc(-c4c(C)noc4C)c(OC[C@H]4CCNC4)cc...
# 9090      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#      standard_value
# 0             750.0
# 1             100.0
# 2           50000.0
# 3             300.0
# 4             800.0
# ...             ...
# 9086          160.0
# 9087        7943.28
# 9088       100000.0
# 9089       63095.73
# 9090        10000.0
#
# [6369 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6364      CHEMBL2238282              O=C(/C=C/c1ccc(N2CCCCC2)cc1)c1sccc1Cl
# 6365      CHEMBL4636881  CC(=O)Nc1c(F)cc(C(=O)N[C@H]2CC[C@H](O)CC2)cc1O...
# 6366      CHEMBL4635134          CNC(=O)c1cc(C(=O)NC2CC2)cn(Cc2ccccc2)c1=O
# 6367      CHEMBL4639128  COCc1nc2cnc3cc(-c4c(C)noc4C)c(OC[C@H]4CCNC4)cc...
# 6368      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#       standard_value         class
# 0             750.00        active
# 1             100.00        active
# 2           50000.00      inactive
# 3             300.00        active
# 4             800.00        active
# ...              ...           ...
# 6364          160.00        active
# 6365         7943.28  intermediate
# 6366       100000.00      inactive
# 6367        63095.73      inactive
# 6368        10000.00      inactive
#
# [6369 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 91%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 80%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 7300
# -rw-rw-r-- 1 bruno bruno 5200159 jul  6 16:28 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-rw-r-- 1 bruno bruno  468001 jul  6 16:34 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-rw-r-- 1 bruno bruno  526341 jul  6 16:34 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-rw-r-- 1 bruno bruno  645598 jul  6 16:34 acetylcholinesterase.zip
# -rw-rw-r-- 1 bruno bruno  101973 jul  6 16:33 CDD_ML_Part_1_Acetylcholinesterase_Bioactivity_Data_Concised.ipynb
# -rw-rw-r-- 1 bruno bruno  313244 jul  6 15:49 CDD_ML_Part_2_Acetylcholinesterase_Exploratory_Data_Analysis.ipynb
# -rw-rw-r-- 1 bruno bruno  208719 jul  6 15:49 CDD_ML_Part_3_Acetylcholinesterase_Descriptor_Dataset_Preparation.ipynb

# %% [markdown]
# ---
